# %% [markdown]
# # Módulo 06 Tarefa 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib notebook

sinasc = pd.read_csv('base_sinac.csv')
sinasc.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
## sinasc.IDADEMAE.value_counts().plot(kind = 'bar')

plt.boxplot(sinasc['IDADEMAE'])
# Out:
# <img src="data:image/png;base64,..." width="640">
# {'whiskers': [<matplotlib.lines.Line2D at 0x188de90b7f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x188de90bc70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x188de915e10>],
#  'medians': [<matplotlib.lines.Line2D at 0x188de9100d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x188de910370>],
#  'means': []}

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
fig, ax = plt.subplots()
plt.boxplot(sinasc['PESO'])
# Out:
# <img src="data:image/png;base64,..." width="640">
# {'whiskers': [<matplotlib.lines.Line2D at 0x188de9a7190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x188df5e2dd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x188de9b3c10>],
#  'medians': [<matplotlib.lines.Line2D at 0x188df5e3310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x188df5e35b0>],
#  'means': []}

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
##plt.boxplot(sinasc['IDADEMAE'])
fig, ax = plt.subplots()
sinasc.IDADEMAE.plot.hist(bins = 20)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
fig, ax = plt.subplots()
sinasc.PESO.plot.hist(bins = 20)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Axes: ylabel='Frequency'>

# %%
s
# Out:
# ORIGEM
# CODESTAB
# CODMUNNASC
# LOCNASC
# IDADEMAE
# ESTCIVMAE
# ESCMAE
# CODOCUPMAE
# QTDFILVIVO
# QTDFILMORT
# CODMUNRES
# GESTACAO
# GRAVIDEZ
# PARTO
# CONSULTAS
# DTNASC
# HORANASC
# SEXO
# APGAR1
# APGAR5
# RACACOR
# PESO
# IDANOMAL
# DTCADASTRO
# CODANOMAL
# NUMEROLOTE
# VERSAOSIST
# DTRECEBIM
# DIFDATA
# DTRECORIGA
# NATURALMAE
# CODMUNNATU
# CODUFNATU
# ESCMAE2010
# SERIESCMAE
# DTNASCMAE
# RACACORMAE
# QTDGESTANT
# QTDPARTNOR
# QTDPARTCES
# IDADEPAI
# DTULTMENST
# SEMAGESTAC
# TPMETESTIM
# CONSPRENAT
# MESPRENAT
# TPAPRESENT
# STTRABPART
# STCESPARTO
# TPNASCASSI
# TPFUNCRESP
# TPDOCRESP
# DTDECLARAC
# ESCMAEAGR1
# STDNEPIDEM
# STDNNOVA
# CODPAISRES
# TPROBSON
# PARIDADE
# KOTELCHUCK
# CONTADOR
# munResStatus
# munResTipo
# munResNome
# munResUf
# munResLat
# munResLon
# munResAlt
# munResArea
